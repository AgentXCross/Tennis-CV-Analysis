# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (1.2.2)
#
# [notice] A new release of pip is available: 25.2 -> 26.1
# [notice] To update, run: pip install --upgrade pip

# %%
from dotenv import load_dotenv
import os
load_dotenv()
api_key = os.getenv("API_KEY")

# %%
# Access Dataset
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key=api_key)
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.3.6-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: certifi in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from roboflow) (2026.4.22)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from roboflow) (1.5.0)
# Requirement already satisfied: matplotlib in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from roboflow) (3.10.9)
# Requirement already satisfied: numpy>=1.18.5 in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from roboflow) (2.4.4)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from roboflow) (12.2.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.3.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.3 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.2 kB)
# Requirement already satisfied: python-dateutil in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: requests in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from roboflow) (2.33.1)
# Requirement already satisfied: six in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from roboflow) (2.6.3)
# Collecting tqdm>=4.41.0 (from roboflow)
#   Using cached tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from roboflow) (6.0.3)
# Collecting requests_toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting typer>=0.12.0 (from roboflow)
#   Downloading typer-0.25.0-py3-none-any.whl.metadata (15 kB)
# Collecting click>=8.2.1 (from typer>=0.12.0->roboflow)
#   Downloading click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.12.0->roboflow)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer>=0.12.0->roboflow)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer>=0.12.0->roboflow)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer>=0.12.0->roboflow)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from rich>=13.8.0->typer>=0.12.0->roboflow) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.12.0->roboflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from matplotlib->roboflow) (4.62.1)
# Requirement already satisfied: packaging>=20.0 in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from matplotlib->roboflow) (26.2)
# Requirement already satisfied: pyparsing>=3 in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/liu_michael/Documents/tennis-cv-analysis/venv/lib/python3.13/site-packages (from requests->roboflow) (3.4.7)
# Downloading roboflow-1.3.6-py3-none-any.whl (184 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 20.3 MB/s  0:00:02m0:00:0100:01
# Downloading pi_heif-1.3.0-cp313-cp313-macosx_11_0_arm64.whl (942 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 942.3/942.3 kB 18.1 MB/s  0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp313-cp313-macosx_11_0_arm64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 23.4 MB/s  0:00:00
# Using cached tqdm-4.67.3-py3-none-any.whl (78 kB)
# Downloading typer-0.25.0-py3-none-any.whl (55 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading click-8.3.3-py3-none-any.whl (110 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: pillow-avif-plugin, filetype, tqdm, shellingham, python-dotenv, pi-heif, opencv-python-headless, mdurl, idna, click, annotated-doc, markdown-it-py, rich, requests_toolbelt, typer, roboflow
#   Attempting uninstall: idna╺━━━━━━━━━━━━━━━━━━━━━━━━  6/16 [opencv-python-headless]
#     Found existing installation: idna 3.13━━━━━━━━━━━━━━━━━━━━  6/16 [opencv-python-headless]
#     Uninstalling idna-3.13:m╺━━━━━━━━━━━━━━━━━━━━━━━━  6/16 [opencv-python-headless]
#       Successfully uninstalled idna-3.13━━━━━━━━━━━━━━━━━━━━━━  6/16 [opencv-python-headless]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [roboflow]/16 [roboflow]toolbelt]]
# Successfully installed annotated-doc-0.0.4 click-8.3.3 filetype-1.2.0 idna-3.7 markdown-it-py-4.0.0 mdurl-0.1.2 opencv-python-headless-4.10.0.84 pi-heif-1.3.0 pillow-avif-plugin-1.5.5 python-dotenv-1.2.2 requests_toolbelt-1.0.0 rich-15.0.0 roboflow-1.3.6 shellingham-1.5.4 tqdm-4.67.3 typer-0.25.0
#
# [notice] A new release of pip is available: 25.2 -> 26.1
# [notice] To update, run: pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in tennis-ball-detection-6 to yolov5pytorch:: 100%|██████████| 52040/52040 [00:12<00:00, 4108.67it/s]
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 5386.38it/s]

# %%
import shutil

shutil.move("tennis-ball-detection-6/train", 
            "tennis-ball-detection-6/tennis-ball-detection-6/train")

shutil.move("tennis-ball-detection-6/test", 
            "tennis-ball-detection-6/tennis-ball-detection-6/test")

shutil.move("tennis-ball-detection-6/valid", 
            "tennis-ball-detection-6/tennis-ball-detection-6/valid")
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yml epochs=100 imgsz=640 device=mps
